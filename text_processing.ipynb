# %% [markdown]
# # Text Processing
#
# ## Capturing Text Data
#
# ### Plain Text

# %%
import os

# Read in a plain text file
with open(os.path.join("data", "hieroglyph.txt"), "r") as f:
    text = f.read()
    print(text)
# Out:
# Hieroglyphic writing dates from c. 3000 BC, and is composed of hundreds of symbols. A hieroglyph can represent a word, a sound, or a silent determinative; and the same symbol can serve different purposes in different contexts. Hieroglyphs were a formal script, used on stone monuments and in tombs, that could be as detailed as individual works of art.

# %% [markdown]
# ### Tabular Data

# %%
import pandas as pd

# Extract text column from a dataframe
df = pd.read_csv(os.path.join("data", "news.csv"))
df.head()[['publisher', 'title']]

# Convert text column to lowercase
df['title'] = df['title'].str.lower()
df.head()[['publisher', 'title']]
# Out:
#       publisher                                              title
# 0      Livemint  fed's charles plosser sees high bar for change...
# 1  IFA Magazine  us open: stocks fall after fed official hints ...
# 2  IFA Magazine  fed risks falling 'behind the curve', charles ...
# 3     Moneynews  fed's plosser: nasty weather has curbed job gr...
# 4        NASDAQ  plosser: fed may have to accelerate tapering pace

# %% [markdown]
# ### Online Resource

# %%
import requests
import json

# Fetch data from a REST API
r = requests.get(
    "https://quotes.rest/qod.json")
res = r.json()
print(json.dumps(res, indent=4))

# Extract relevant object and field
q = res["contents"]["quotes"][0]
print(q["quote"], "\n--", q["author"])
# Out:
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# /anaconda/envs/aind/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# /anaconda/envs/aind/lib/python3.6/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1805         result = _lib.SSL_do_handshake(self._ssl)
# -> 1806         self._raise_ssl_error(self._ssl, result)
#    1807
#
# /anaconda/envs/aind/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1538                         raise SysCallError(errno, errorcode.get(errno))
# -> 1539                 raise SysCallError(-1, "Unexpected EOF")
#    1540             else:
#
# SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# /anaconda/envs/aind/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# /anaconda/envs/aind/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# /anaconda/envs/aind/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# /anaconda/envs/aind/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#
# /anaconda/envs/aind/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#
# /anaconda/envs/aind/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     447             except OpenSSL.SSL.Error as e:
# --> 448                 raise ssl.SSLError('bad handshake: %r' % e)
#     449             break
#
# SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /anaconda/envs/aind/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# /anaconda/envs/aind/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# /anaconda/envs/aind/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='quotes.rest', port=443): Max retries exceeded with url: /qod.json (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-3-36b4a02206b4> in <module>()
#       4 # Fetch data from a REST API
#       5 r = requests.get(
# ----> 6     "https://quotes.rest/qod.json")
#       7 res = r.json()
#       8 print(json.dumps(res, indent=4))
#
# /anaconda/envs/aind/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /anaconda/envs/aind/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda/envs/aind/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /anaconda/envs/aind/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /anaconda/envs/aind/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     504             if isinstance(e.reason, _SSLError):
#     505                 # This branch is for urllib3 v1.22 and later.
# --> 506                 raise SSLError(e, request=request)
#     507
#     508             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='quotes.rest', port=443): Max retries exceeded with url: /qod.json (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))

# %% [markdown]
# ## Cleaning

# %%
import requests

# Fetch a web page
r = requests.get("https://www.udacity.com/courses/all")
print(r.text)
# Out:
# <!DOCTYPE html><html><head><meta charset="utf-8"><title>Udacity | Udacity</title><base href="/"><meta name="viewport" content="width=device-width,initial-scale=1"><link rel="icon" type="image/x-icon" href="favicon.ico"><script src="/assets/vendor/segment.js" async=""></script><link href="styles.92f29c1253ee570886d4.bundle.css" rel="stylesheet"><style ng-transition="iridium-us">html[_ngcontent-c0]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c0], [_ngcontent-c0]:after, [_ngcontent-c0]:before{-webkit-box-sizing:inherit;box-sizing:inherit}a[_ngcontent-c0]{color:#9400d3}body[_ngcontent-c0]{color:#028bb1}[_nghost-c0]{display:block;position:relative}</style><style ng-transition="iridium-us">html[_ngcontent-c1]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c1], [_ngcontent-c1]:after, [_ngcontent-c1]:before{-webkit-box-sizing:inherit;box-sizing:inherit}.invisible[_ngcontent-c1]{visibility:hidden!important}.hide[_ngcontent-c1]{display:none!important}.show[_ngcontent-c1]{display:block!important}.sr-only[_ngcontent-c1]{height:1px;width:1px;overflow:hidden;position:absolute!important;clip:rect(1px,1px,1px,1px)}.hidden-xs-up[_ngcontent-c1]{display:none!important}@media (max-width:479px){.hidden-xs-down[_ngcontent-c1]{display:none!important}}@media (min-width:480px){.hidden-sm-up[_ngcontent-c1]{display:none!important}}@media (max-width:767px){.hidden-sm-down[_ngcontent-c1]{display:none!important}}@media (min-width:768px){.hidden-md-up[_ngcontent-c1]{display:none!important}}@media (max-width:991px){.hidden-md-down[_ngcontent-c1]{display:none!important}}@media (min-width:992px){.hidden-lg-up[_ngcontent-c1]{display:none!important}}@media (max-width:1179px){.hidden-lg-down[_ngcontent-c1]{display:none!important}}@media (min-width:1180px){.hidden-xl-up[_ngcontent-c1]{display:none!important}}.hidden-xl-down[_ngcontent-c1], .visible-print-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-block[_ngcontent-c1]{display:block!important}}.visible-print-inline[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline[_ngcontent-c1]{display:inline!important}}.visible-print-inline-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline-block[_ngcontent-c1]{display:inline-block!important}}@media print{.hidden-print[_ngcontent-c1]{display:none!important}}#contain-all[_ngcontent-c1]{width:100%;overflow:hidden;background:#fff;-webkit-backface-visibility:hidden;backface-visibility:hidden;-webkit-transform-style:preserve-3d}.outer_contain[_ngcontent-c1]{margin:0 auto;max-width:90rem}.contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto;padding-top:3rem;padding-bottom:3rem;padding-left:1.5rem;padding-right:1.5rem}.contain[_ngcontent-c1]:after{clear:both;content:"";display:table}@media screen and (min-width:48rem){.contain[_ngcontent-c1]{padding-top:6rem;padding-bottom:6rem}}@media screen and (min-width:73.75rem){.contain[_ngcontent-c1]{padding-left:0;padding-right:0}}.contain.no-padding[_ngcontent-c1]{padding:0}.contain.no-padding-top[_ngcontent-c1]{padding-top:0}.contain--none[_ngcontent-c1], .contain.no-padding-bottom[_ngcontent-c1]{padding-bottom:0}.contain--none[_ngcontent-c1]{padding-top:0;margin:0 auto}@media screen and (min-width:48rem){.contain--none[_ngcontent-c1]{padding-top:0;padding-bottom:0}}.contain--small[_ngcontent-c1]{padding-top:3rem;padding-bottom:3rem;margin:0 auto}@media screen and (min-width:48rem){.contain--small[_ngcontent-c1]{padding-top:4.5rem;padding-bottom:4.5rem}}.cards_contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto}.cards_contain[_ngcontent-c1]:after{clear:both;content:"";display:table}[_ngcontent-c1]:target:before{content:"";display:inline-block;height:130px;margin:-130px 0 0}.header[_ngcontent-c1]{max-width:100%;margin-left:auto;margin-right:auto}.header[_ngcontent-c1]:after{clear:both;content:"";display:table}.header.header--clone[_ngcontent-c1]{width:100%;top:-1000px}.header.head ...
# Students will learn how to use header files, control flow, functions, classes.</span></div><!----></div></div><div _ngcontent-c128="" class="course-summary-card row row-gap-medium"><div _ngcontent-c128="" class="col-sm-3"><!----><img _ngcontent-c128="" class="course-thumb img-responsive img-bordered center-block" height="170" width="290" src="https://d20vrrgs8k4bvw.cloudfront.net/images/courses/thumbnails/cx43_thumbnail.jpg" alt="React Fundamentals"><!----><!----></div><div _ngcontent-c128="" class="col-sm-9 course-text"><div _ngcontent-c128="" class="row"><div _ngcontent-c128="" class="col-sm-8"><h3 _ngcontent-c128="" class="h-slim"><a _ngcontent-c128="" href="/course/react-fundamentals--cx43"> React Fundamentals</a><span _ngcontent-c128="" class="badges"><!----><span _ngcontent-c128="" class="badge badge-squared badge-new text-uppercase">New</span></span></h3></div><div _ngcontent-c128="" class="col-sm-4 hidden-xs"><!----><span _ngcontent-c128="" class="caption text-right"><span _ngcontent-c128="" data-course-level-icon="" class="icon-level course-info-bar-icon icon-level-intermediate" classname="icon-level course-info-bar-icon icon-level-intermediate"></span><span _ngcontent-c128="" class="capitalize" data-course-level-label="">intermediate</span></span></div></div><div _ngcontent-c128=""><!----><span _ngcontent-c128="" innerhtml="By learning React's component model, you'll be able to write declarative, composable user interfaces to build production-ready apps.">By learning React's component model, you'll be able to write declarative, composable user interfaces to build production-ready apps.</span></div><!----></div></div><div _ngcontent-c128="" class="course-summary-card row row-gap-medium"><div _ngcontent-c128="" class="col-sm-3"><!----><img _ngcontent-c128="" class="course-thumb img-responsive img-bordered center-block" height="170" width="290" src="https://d20vrrgs8k4bvw.cloudfront.net/images/courses/thumbnails/cx44_thumbnail.jpg" alt="React &amp; Redux"><!----><!----></div><div _ngcontent-c128="" class="col-sm-9 course-text"><div _ngcontent-c128="" class="row"><div _ngcontent-c128="" class="col-sm-8"><h3 _ngcontent-c128="" class="h-slim"><a _ngcontent-c128="" href="/course/react-redux--cx44"> React &amp; Redux</a><span _ngcontent-c128="" class="badges"><!----><span _ngcontent-c128="" class="badge badge-squared badge-new text-uppercase">New</span></span></h3></div><div _ngcontent-c128="" class="col-sm-4 hidden-xs"><!----><span _ngcontent-c128="" class="caption text-right"><span _ngcontent-c128="" data-course-level-icon="" class="icon-level course-info-bar-icon icon-level-advanced" classname="icon-level course-info-bar-icon icon-level-advanced"></span><span _ngcontent-c128="" class="capitalize" data-course-level-label="">advanced</span></span></div></div><div _ngcontent-c128=""><!----><span _ngcontent-c128="" innerhtml="By learning Redux, you'll manage complicated state to build enterprise-level apps.">By learning Redux, you'll manage complicated state to build enterprise-level apps.</span></div><!----></div></div><div _ngcontent-c128="" class="course-summary-card row row-gap-medium"><div _ngcontent-c128="" class="col-sm-3"><!----><img _ngcontent-c128="" class="course-thumb img-responsive img-bordered center-block" height="170" width="290" src="https://d20vrrgs8k4bvw.cloudfront.net/images/courses/thumbnails/cx45_thumbnail.jpg" alt="React Native"><!----><!----></div><div _ngcontent-c128="" class="col-sm-9 course-text"><div _ngcontent-c128="" class="row"><div _ngcontent-c128="" class="col-sm-8"><h3 _ngcontent-c128="" class="h-slim"><a _ngcontent-c128="" href="/course/react-native--cx45"> React Native</a><span _ngcontent-c128="" class="badges"><!----><span _ngcontent-c128="" class="badge badge-squared badge-new text-uppercase">New</span></span></h3></div><div _ngcontent-c128="" class="col-sm-4 hidden-xs"><!----><span _ngcontent-c128="" class="caption text-right"><span _ngcontent-c128="" data-course-level-icon="" class="ico ...

# %%
import re

# Remove HTML tags using RegEx
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
# Udacity | Udacityhtml[_ngcontent-c0]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c0], [_ngcontent-c0]:after, [_ngcontent-c0]:before{-webkit-box-sizing:inherit;box-sizing:inherit}a[_ngcontent-c0]{color:#9400d3}body[_ngcontent-c0]{color:#028bb1}[_nghost-c0]{display:block;position:relative}html[_ngcontent-c1]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c1], [_ngcontent-c1]:after, [_ngcontent-c1]:before{-webkit-box-sizing:inherit;box-sizing:inherit}.invisible[_ngcontent-c1]{visibility:hidden!important}.hide[_ngcontent-c1]{display:none!important}.show[_ngcontent-c1]{display:block!important}.sr-only[_ngcontent-c1]{height:1px;width:1px;overflow:hidden;position:absolute!important;clip:rect(1px,1px,1px,1px)}.hidden-xs-up[_ngcontent-c1]{display:none!important}@media (max-width:479px){.hidden-xs-down[_ngcontent-c1]{display:none!important}}@media (min-width:480px){.hidden-sm-up[_ngcontent-c1]{display:none!important}}@media (max-width:767px){.hidden-sm-down[_ngcontent-c1]{display:none!important}}@media (min-width:768px){.hidden-md-up[_ngcontent-c1]{display:none!important}}@media (max-width:991px){.hidden-md-down[_ngcontent-c1]{display:none!important}}@media (min-width:992px){.hidden-lg-up[_ngcontent-c1]{display:none!important}}@media (max-width:1179px){.hidden-lg-down[_ngcontent-c1]{display:none!important}}@media (min-width:1180px){.hidden-xl-up[_ngcontent-c1]{display:none!important}}.hidden-xl-down[_ngcontent-c1], .visible-print-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-block[_ngcontent-c1]{display:block!important}}.visible-print-inline[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline[_ngcontent-c1]{display:inline!important}}.visible-print-inline-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline-block[_ngcontent-c1]{display:inline-block!important}}@media print{.hidden-print[_ngcontent-c1]{display:none!important}}#contain-all[_ngcontent-c1]{width:100%;overflow:hidden;background:#fff;-webkit-backface-visibility:hidden;backface-visibility:hidden;-webkit-transform-style:preserve-3d}.outer_contain[_ngcontent-c1]{margin:0 auto;max-width:90rem}.contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto;padding-top:3rem;padding-bottom:3rem;padding-left:1.5rem;padding-right:1.5rem}.contain[_ngcontent-c1]:after{clear:both;content:"";display:table}@media screen and (min-width:48rem){.contain[_ngcontent-c1]{padding-top:6rem;padding-bottom:6rem}}@media screen and (min-width:73.75rem){.contain[_ngcontent-c1]{padding-left:0;padding-right:0}}.contain.no-padding[_ngcontent-c1]{padding:0}.contain.no-padding-top[_ngcontent-c1]{padding-top:0}.contain--none[_ngcontent-c1], .contain.no-padding-bottom[_ngcontent-c1]{padding-bottom:0}.contain--none[_ngcontent-c1]{padding-top:0;margin:0 auto}@media screen and (min-width:48rem){.contain--none[_ngcontent-c1]{padding-top:0;padding-bottom:0}}.contain--small[_ngcontent-c1]{padding-top:3rem;padding-bottom:3rem;margin:0 auto}@media screen and (min-width:48rem){.contain--small[_ngcontent-c1]{padding-top:4.5rem;padding-bottom:4.5rem}}.cards_contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto}.cards_contain[_ngcontent-c1]:after{clear:both;content:"";display:table}[_ngcontent-c1]:target:before{content:"";display:inline-block;height:130px;margin:-130px 0 0}.header[_ngcontent-c1]{max-width:100%;margin-left:auto;margin-right:auto}.header[_ngcontent-c1]:after{clear:both;content:"";display:table}.header.header--clone[_ngcontent-c1]{width:100%;top:-1000px}.header.header--clone[_ngcontent-c1]   .header__navbar[_ngcontent-c1]{height:4.5rem}.header.header--stick[_ngcontent-c1]{top:0;background-color:#fff;z-index:8000;-webkit-box-shadow:0 1px 2px rgba(0,0,0,.1);box-shadow:0 1px 2px rgba(0,0,0,.1)}.header__navbar[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto;height:4.5rem;padding:0 1.5em}.header__navbar[_ngcontent-c1]:after{clear:both;content:"";d ...
# Students will learn how to use header files, control flow, functions, classes. React FundamentalsNewintermediateBy learning React's component model, you'll be able to write declarative, composable user interfaces to build production-ready apps. React &amp; ReduxNewadvancedBy learning Redux, you'll manage complicated state to build enterprise-level apps. React NativeNewadvancedUsing React Native, you’ll be able to develop native applications that run on both iOS and Android devices. Kotlin for Android DevelopersNewadvancedTake an Android app in Java and convert it to Kotlin, learning key features of the Kotlin programming language along the way. Object-Oriented JavaScriptintermediateLearn how to build objects, create classes, and manage inheritance with object-oriented JavaScript. JavaScript and the DOMintermediateDiscover how the DOM is created and learn to programmatically control the page using JavaScript.Nanodegree ProgramsAndroid BasicsAndroid DeveloperBecome an iOS DeveloperBusiness AnalystData AnalystFront-End Web DeveloperFull Stack Web DeveloperIntro to ProgrammingReactOnly At UdacityArtificial IntelligenceDeep Learning FoundationsDigital MarketingMachine Learning EngineerRoboticsSelf-Driving Car EngineerVR DeveloperSupportContact UsHelp and FAQService StatusResourcesFree Course CatalogCareer Resource CenterHiring PartnersStudent SuccessFor BusinessUdacity for BusinessCorporate TrainingHire GraduatesAbout UdacityAboutBlogIn the NewsJobsMobile© 2011–2018 Udacity, Inc.Legal &amp; PrivacyRegulatory InformationSite MapUnited StatesBrasilChinaEuropeGermanyIndia"Nanodegree" is a registered trademark of Udacity. © 2011–2018 Udacity, Inc.Udacity is not an accredited university and we don't confer traditional degrees. Udacity Nanodegree programs represent collaborations with our industry partners who help us develop our content and who hire many of our program graduates.{&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavLinks&a;locale=en-US&q;:[{&q;href&q;:&q;/nanodegree&q;,&q;text&q;:&q;Nanodegrees&q;},{&q;href&q;:&q;/courses/all&q;,&q;text&q;:&q;Free Courses&q;},{&q;href&q;:&q;/business&q;,&q;text&q;:&q;For Business&q;}],&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavAuthMobileLinks&a;locale=en-US&q;:{&q;isAuth&q;:[{&q;text&q;:&q;Blog&q;,&q;href&q;:&q;http://blog.udacity.com/&q;},{&q;text&q;:&q;My Classroom&q;,&q;href&q;:&q;https://classroom.udacity.com/&q;,&q;classes&q;:[&q;blue&q;]}],&q;isNotAuth&q;:[{&q;text&q;:&q;Sign In&q;,&q;href&q;:&q;https://auth.udacity.com/sign-in?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;blue&q;]},{&q;text&q;:&q;Get Started&q;,&q;href&q;:&q;https://auth.udacity.com/sign-up?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;turquoise&q;]}]},&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerSpecialUrlLinks&a;locale=en-US&q;:[],&q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavAuthLinks&a;locale=en-US&q;:{&q;isAuth&q;:[{&q;text&q;:&q;Blog&q;,&q;href&q;:&q;http://blog.udacity.com/&q;},{&q;text&q;:&q;My Classroom&q;,&q;href&q;:&q;https://classroom.udacity.com/&q;,&q;classes&q;:[&q;button--primary&q;]}],&q;isNotAuth&q;:[{&q;text&q;:&q;Sign In&q;,&q;href&q;:&q;https://auth.udacity.com/sign-in?next=https://classroom.udacity.com/authenticated&q;},{&q;text&q;:&q;Get Started&q;,&q;href&q;:&q;https://auth.udacity.com/sign-up?next=https://classroom.udacity.com/authenticated&q;,&q;classes&q;:[&q;button--turquoise&q;]}]},&q;/courses/all@CACHE_TRACK_FILTERS&a;locale=en-us&q;:[{&q;name&q;:&q;All&q;,&q;key&q;:&q;all&q;},{&q;name&q;:&q;Android&q;,&q;key&q;:&q;android&q;},{&q;name&q;:&q;Artificial Intelligence&q;,&q;key&q;:&q;artificial-intelligence&q;},{&q;name&q;:&q;Data Analytics&q;,&q;key&q;:&q;data-analytics&q;},{&q;name&q;:&q;Data Science&q;,&q;key&q;:&q;data-science&q;},{&q;name&q;:&q;Deep Learning&q;,&q;key&q;:&q;deep-learning&q;},{&q;name&q;:&q;Developer Essentials&q;,&q;key&q;:&q;developer-essentials&q;},{&q;name&q;:&q;Digital Marketing&q;,&q;key&q;:&q;d ...

# %%
from bs4 import BeautifulSoup

# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
# Udacity | Udacityhtml[_ngcontent-c0]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c0], [_ngcontent-c0]:after, [_ngcontent-c0]:before{-webkit-box-sizing:inherit;box-sizing:inherit}a[_ngcontent-c0]{color:#9400d3}body[_ngcontent-c0]{color:#028bb1}[_nghost-c0]{display:block;position:relative}html[_ngcontent-c1]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c1], [_ngcontent-c1]:after, [_ngcontent-c1]:before{-webkit-box-sizing:inherit;box-sizing:inherit}.invisible[_ngcontent-c1]{visibility:hidden!important}.hide[_ngcontent-c1]{display:none!important}.show[_ngcontent-c1]{display:block!important}.sr-only[_ngcontent-c1]{height:1px;width:1px;overflow:hidden;position:absolute!important;clip:rect(1px,1px,1px,1px)}.hidden-xs-up[_ngcontent-c1]{display:none!important}@media (max-width:479px){.hidden-xs-down[_ngcontent-c1]{display:none!important}}@media (min-width:480px){.hidden-sm-up[_ngcontent-c1]{display:none!important}}@media (max-width:767px){.hidden-sm-down[_ngcontent-c1]{display:none!important}}@media (min-width:768px){.hidden-md-up[_ngcontent-c1]{display:none!important}}@media (max-width:991px){.hidden-md-down[_ngcontent-c1]{display:none!important}}@media (min-width:992px){.hidden-lg-up[_ngcontent-c1]{display:none!important}}@media (max-width:1179px){.hidden-lg-down[_ngcontent-c1]{display:none!important}}@media (min-width:1180px){.hidden-xl-up[_ngcontent-c1]{display:none!important}}.hidden-xl-down[_ngcontent-c1], .visible-print-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-block[_ngcontent-c1]{display:block!important}}.visible-print-inline[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline[_ngcontent-c1]{display:inline!important}}.visible-print-inline-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline-block[_ngcontent-c1]{display:inline-block!important}}@media print{.hidden-print[_ngcontent-c1]{display:none!important}}#contain-all[_ngcontent-c1]{width:100%;overflow:hidden;background:#fff;-webkit-backface-visibility:hidden;backface-visibility:hidden;-webkit-transform-style:preserve-3d}.outer_contain[_ngcontent-c1]{margin:0 auto;max-width:90rem}.contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto;padding-top:3rem;padding-bottom:3rem;padding-left:1.5rem;padding-right:1.5rem}.contain[_ngcontent-c1]:after{clear:both;content:"";display:table}@media screen and (min-width:48rem){.contain[_ngcontent-c1]{padding-top:6rem;padding-bottom:6rem}}@media screen and (min-width:73.75rem){.contain[_ngcontent-c1]{padding-left:0;padding-right:0}}.contain.no-padding[_ngcontent-c1]{padding:0}.contain.no-padding-top[_ngcontent-c1]{padding-top:0}.contain--none[_ngcontent-c1], .contain.no-padding-bottom[_ngcontent-c1]{padding-bottom:0}.contain--none[_ngcontent-c1]{padding-top:0;margin:0 auto}@media screen and (min-width:48rem){.contain--none[_ngcontent-c1]{padding-top:0;padding-bottom:0}}.contain--small[_ngcontent-c1]{padding-top:3rem;padding-bottom:3rem;margin:0 auto}@media screen and (min-width:48rem){.contain--small[_ngcontent-c1]{padding-top:4.5rem;padding-bottom:4.5rem}}.cards_contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto}.cards_contain[_ngcontent-c1]:after{clear:both;content:"";display:table}[_ngcontent-c1]:target:before{content:"";display:inline-block;height:130px;margin:-130px 0 0}.header[_ngcontent-c1]{max-width:100%;margin-left:auto;margin-right:auto}.header[_ngcontent-c1]:after{clear:both;content:"";display:table}.header.header--clone[_ngcontent-c1]{width:100%;top:-1000px}.header.header--clone[_ngcontent-c1]   .header__navbar[_ngcontent-c1]{height:4.5rem}.header.header--stick[_ngcontent-c1]{top:0;background-color:#fff;z-index:8000;-webkit-box-shadow:0 1px 2px rgba(0,0,0,.1);box-shadow:0 1px 2px rgba(0,0,0,.1)}.header__navbar[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto;height:4.5rem;padding:0 1.5em}.header__navbar[_ngcontent-c1]:after{clear:both;content:"";d ...

# %%
# Find all course summaries
soup.find_all("div", class_="course-summary-card")
#summaries = soup.find_all("div", class_="course-summary-card")
#summaries[0]
# Out:
# []

# %%
# Extract title
summaries[0].select_one("h3 a").get_text().strip()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-0a50e9f541b4> in <module>()
#       1 # Extract title
# ----> 2 summaries[0].select_one("h3 a").get_text().strip()
#
# IndexError: list index out of range

# %%
# Extract description
summaries[0].select_one("div[data-course-short-summary]").get_text().strip()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-e0d9ff8446d4> in <module>()
#       1 # Extract description
# ----> 2 summaries[0].select_one("div[data-course-short-summary]").get_text().strip()
#
# IndexError: list index out of range

# %%
# Find all course summaries, extract title and description
courses = []
summaries = soup.find_all("div", class_="course-summary-card")
for summary in summaries:
    title = summary.select_one("h3 a").get_text().strip()
    description = summary.select_one("div[data-course-short-summary]").get_text().strip()
    courses.append((title, description))

print(len(courses), "course summaries found. Sample:")
print(courses[0][0])
print(courses[0][1])

# %% [markdown]
# ## Normalization

# %% [markdown]
# ### Case Normalization

# %%
# Sample text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"
print(text)

# %%
# Convert to lowercase
text = text.lower() 
print(text)

# %% [markdown]
# ### Punctuation Removal

# %%
import re

# Remove punctuation characters
text = re.sub(r"[^a-zA-Z0-9]", " ", text) 
print(text)

# %% [markdown]
# ## Tokenization

# %%
# Split text into tokens (words)
words = text.split()
print(words)

# %% [markdown]
# ### NLTK: Natural Language ToolKit

# %%
# Another sample text
text = "Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers."
print(text)

# %%
from nltk.tokenize import word_tokenize

# Split text into words using NLTK
words = word_tokenize(text)
print(words)

# %%
from nltk.tokenize import sent_tokenize

# Split text into sentences
sentences = sent_tokenize(text)
print(sentences)

# %%
# List stop words
from nltk.corpus import stopwords
print(stopwords.words("english"))

# %%
# Reset text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"

# Normalize it
text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())

# Tokenize it
words = text.split()
print(words)

# %%
# Remove stop words
words = [w for w in words if w not in stopwords.words("english")]
print(words)

# %% [markdown]
# ## Part-of-Speech Tagging

# %%
from nltk import pos_tag

# Tag parts of speech (PoS)
sentence = word_tokenize("I always lie down to tell a lie.")
pos_tag(sentence)

# %% [markdown]
# ### Sentence Parsing

# %%
import nltk

# Define a custom grammar
my_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")
parser = nltk.ChartParser(my_grammar)

# Parse a sentence
sentence = word_tokenize("I shot an elephant in my pajamas")
for tree in parser.parse(sentence):
    print(tree)

# %%
import IPython  # for displaying parse trees inline

# Visualize parse trees
for tree in parser.parse(sentence):
    IPython.display.display(tree)  # instead of tree.draw()

# %%
from nltk import pos_tag, ne_chunk
from nltk.tokenize import word_tokenize

# Recognize named entities in a tagged sentence
tree = ne_chunk(pos_tag(word_tokenize("Antonio joined Udacity Inc. in California.")))
IPython.display.display(tree)

# %% [markdown]
# ## Stemming & Lemmatization
#
# ### Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)

# %%
# Lemmatize verbs by specifying pos
lemmed = [WordNetLemmatizer().lemmatize(w, pos='v') for w in lemmed]
print(lemmed)
